# %%
# import pandas as pd
# import plotly.express as px

# df = pd.read_csv("https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/active_cases_2020-07-17_0800.csv")

# fig = px.choropleth(
#     df,
#     geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
#     featureidkey='properties.ST_NM',
#     locations='state',
#     color='active cases',
#     color_continuous_scale='Reds'
# )

# fig.update_geos(fitbounds="locations", visible=False)

# fig.show()

# %%
# import git

# repository_url = "https://github.com/PhonePe/pulse.git"

# destination_directory ="D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE/files"

# git.Repo.clone_from(repository_url, destination_directory)

# %%
# #Once created the clone of GIT-HUB repository then,
# #Required libraries for the program
import pandas as pd
import json
import os

# #This is to direct the path to get the data as states

path1=r"D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE\files\data\aggregated\transaction\country\india\state/"
Agg_state_list=os.listdir(path1)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

# Aggregate Transaction

data_1={'State':[], 'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:

    state_path=path1+i+"/"
    
    Agg_yr=os.listdir(state_path)

    for j in Agg_yr:

        year_path=state_path+j+"/"

        Agg_yr_list=os.listdir(year_path)

        for k in Agg_yr_list:

            year_list=year_path+k

            Data=open(year_list,'r')

            D=json.load(Data)

            for z in D['data']['transactionData']:

                Name=z['name']
                data_1['Transaction_type'].append(Name)

                count=z['paymentInstruments'][0]['count']
                data_1['Transaction_count'].append(count)

                amount=z['paymentInstruments'][0]['amount']
                data_1['Transaction_amount'].append(amount)

                data_1['State'].append(i)
                data_1['Year'].append(j)
                data_1['Quarter'].append(int(k.strip('.json')))

#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(data_1)

Agg_Trans["State"] = Agg_Trans["State"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Agg_Trans["State"] = Agg_Trans["State"].str.replace("-"," ").str.title()
Agg_Trans['State'] = Agg_Trans['State'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")
Agg_Trans
# Out:
#                   State  Year  Quarter          Transaction_type  \
# 0     Andaman & Nicobar  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018        1         Merchant payments
# 3     Andaman & Nicobar  2018        1        Financial Services
# 4     Andaman & Nicobar  2018        1                    Others
# ...                 ...   ...      ...                       ...
# 4309        West Bengal  2023        4         Merchant payments
# 4310        West Bengal  2023        4     Peer-to-peer payments
# 4311        West Bengal  2023        4  Recharge & bill payments
# 4312        West Bengal  2023        4        Financial Services
# 4313        West Bengal  2023        4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
# Agg_Trans["State"].unique()

# %%
import pandas as pd
import json
import os

# #This is to direct the path to get the data as states

path2=r"D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE\files\data\aggregated\user\country\india\state/"
Agg_users_list=os.listdir(path2)
Agg_users_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

# Aggregated User

data_2={'State':[], 'Year':[],'Quarter':[],'Brand':[],'Counts':[],'Percentage':[]}

for a in Agg_users_list:

    first_path=path2+a+"/"
    
    yr=os.listdir(first_path)

    for b in yr:

        second_path=first_path+b+"/"

        user_li=os.listdir(second_path)

        for c in user_li:

            last_file=second_path+c

            Data=open(last_file,'r')

            ag_user=json.load(Data)
            
            try:

                for u in ag_user['data']['usersByDevice']:

                    Brand=u['brand']
                    data_2['Brand'].append(Brand)

                    Count1=u['count']
                    data_2['Counts'].append(Count1)

                    Percentage=u['percentage']
                    data_2['Percentage'].append(Percentage)

                    data_2['State'].append(a)

                    data_2['Year'].append(b)

                    data_2['Quarter'].append(int(c.strip('.json')))
            
            except:
                pass

#Succesfully created a dataframe
Agg_Users=pd.DataFrame(data_2)

Agg_Users["State"] = Agg_Users["State"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Agg_Users["State"] = Agg_Users["State"].str.replace("-"," ").str.title()
Agg_Users['State'] = Agg_Users['State'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")
Agg_Users
# Out:
#                   State  Year  Quarter    Brand   Counts  Percentage
# 0     Andaman & Nicobar  2018        1   Xiaomi     1665    0.247033
# 1     Andaman & Nicobar  2018        1  Samsung     1445    0.214392
# 2     Andaman & Nicobar  2018        1     Vivo      982    0.145697
# 3     Andaman & Nicobar  2018        1     Oppo      501    0.074332
# 4     Andaman & Nicobar  2018        1  OnePlus      332    0.049258
# ...                 ...   ...      ...      ...      ...         ...
# 6727        West Bengal  2022        1   Lenovo   330017    0.015056
# 6728        West Bengal  2022        1  Infinix   284678    0.012987
# 6729        West Bengal  2022        1     Asus   280347    0.012790
# 6730        West Bengal  2022        1    Apple   277752    0.012671
# 6731        West Bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
import pandas as pd
import json
import os

# #This is to direct the path to get the data as states

path3=r"D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE\files\data\map\transaction\hover\country\india\state/"
map_transaction_path=os.listdir(path3)
map_transaction_path
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

# Map Transaction

data_3={'State':[], 'Year':[],'Quarter':[],'Districts':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in map_transaction_path:

    map_path=path3+i+"/"
    
    map_yr=os.listdir(map_path)

    for j in map_yr:

        year=map_path+j+"/"

        map_list=os.listdir(year)

        for k in map_list:

            files=year+k

            Data=open(files,'r')

            M=json.load(Data)

            for m in M['data']['hoverDataList']:

                Districts=m['name']
                data_3['Districts'].append(Districts)

                count=m['metric'][0]['count']
                data_3['Transaction_count'].append(count)

                amount=m['metric'][0]['amount']
                data_3['Transaction_amount'].append(amount)

                data_3['State'].append(i)
                data_3['Year'].append(j)
                data_3['Quarter'].append(int(k.strip('.json')))

#Succesfully created a dataframe
Map_Transaction=pd.DataFrame(data_3)

Map_Transaction["State"] = Map_Transaction["State"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Map_Transaction["State"] = Map_Transaction["State"].str.replace("-"," ").str.title()
Map_Transaction['State'] = Map_Transaction['State'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")
Map_Transaction
# Out:
#                    State  Year  Quarter                          Districts  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 17559        West Bengal  2023        4                     nadia district
# 17560        West Bengal  2023        4                   birbhum district
# 17561        West Bengal  2023        4           purba medinipur district
# 17562        West Bengal  2023        4                    maldah district
# 17563        West Bengal  2023        4                 darjiling district
#
#        Transaction_count  Transaction_amount
# ...

# %%
import pandas as pd
import json
import os

# #This is to direct the path to get the data as states

path4=r'D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE\files\data\map\user\hover\country\india\state/'
map_user_path=os.listdir(path4)
map_user_path

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

# Map User

data_4={'State':[], 'Year':[],'Quarter':[],'Districts':[], 'RegisteredUsers':[], 'AppOpens':[]}

for i in map_user_path:

    m_u=path4+i+"/"
    
    m_yr=os.listdir(m_u)

    for j in m_yr:

        map1=m_u+j+"/"

        map_yr_list=os.listdir(map1)

        for k in map_yr_list:

            file=map1+k

            Datas=open(file,'r')

            map_user=json.load(Datas)
            
            for b in map_user['data']['hoverData'].items():

                District = b[0]
                data_4['Districts'].append(District)
                
                RegisteredUsers = b[1]['registeredUsers']
                data_4['RegisteredUsers'].append(RegisteredUsers)
                
                AppOpens = b[1]['appOpens']
                data_4['AppOpens'].append(AppOpens)

                data_4['State'].append(i)
                data_4['Year'].append(j)
                data_4['Quarter'].append(int(k.strip('.json')))

#Succesfully created a dataframe
Map_User=pd.DataFrame(data_4)

Map_User["State"] = Map_User["State"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Map_User["State"] = Map_User["State"].str.replace("-"," ").str.title()
Map_User['State'] = Map_User['State'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")
Map_User
# Out:
#                    State  Year  Quarter                          Districts  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 17563        West Bengal  2023        4                     nadia district
# 17564        West Bengal  2023        4                   birbhum district
# 17565        West Bengal  2023        4           purba medinipur district
# 17566        West Bengal  2023        4                    maldah district
# 17567        West Bengal  2023        4                 darjiling district
#
#        RegisteredUsers  AppOpens
# 0                  632         0
# ...

# %%
import pandas as pd
import json
import os

# #This is to direct the path to get the data as states

path5=r"D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE\files\data\top\transaction\country\india\state/"
top_transaction=os.listdir(path5)
top_transaction
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

# Top Transaction

data_5={'State':[], 'Year':[],'Quarter':[],'Pincodes':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in top_transaction:

    app=path5+i+"/"
    
    map_yr=os.listdir(app)

    for j in map_yr:

        lin=app+j+"/"

        map_list=os.listdir(lin)

        for k in map_list:

            lin2=lin+k

            Data=open(lin2,'r')

            T=json.load(Data)
            
            for t in T["data"]["pincodes"]:
                
                Pincode=t['entityName']
                data_5['Pincodes'].append(Pincode)

                count=t['metric']['count']
                data_5['Transaction_count'].append(count)

                amount=t['metric']['amount']
                data_5['Transaction_amount'].append(amount)

                data_5['State'].append(i)
                data_5['Year'].append(j)
                data_5['Quarter'].append(int(k.strip('.json')))

#Succesfully created a dataframe
Top_Transaction=pd.DataFrame(data_5)

Top_Transaction["State"] = Top_Transaction["State"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Top_Transaction["State"] = Top_Transaction["State"].str.replace("-"," ").str.title()
Top_Transaction['State'] = Top_Transaction['State'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")
Top_Transaction
# Out:
#                   State  Year  Quarter Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2018        1   744101               1622
# 1     Andaman & Nicobar  2018        1   744103               1223
# 2     Andaman & Nicobar  2018        1   744102                969
# 3     Andaman & Nicobar  2018        1   744105                685
# 4     Andaman & Nicobar  2018        1   744104                340
# ...                 ...   ...      ...      ...                ...
# 8562        West Bengal  2023        4   721301            4133775
# 8563        West Bengal  2023        4   700001            3983241
# 8564        West Bengal  2023        4   732125            3950411
# 8565        West Bengal  2023        4   700039            3742452
# 8566        West Bengal  2023        4   700014            3652710
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...

# %%
import pandas as pd
import json
import os

# #This is to direct the path to get the data as states

path6=r"D:\Swetha Documents\Python_Code\CAPSTONE_SEC_PHONEPE\files\data\top\user\country\india\state/"
top_user_path=os.listdir(path6)
top_user_path

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

# Top Users

data_6={'State':[], 'Year':[],'Quarter':[],'Pincodes':[], 'RegisteredUsers':[]}

for i in top_user_path:

    app=path6+i+"/"
    
    map_yr=os.listdir(app)

    for j in map_yr:

        lin=app+j+"/"

        map_list=os.listdir(lin)

        for k in map_list:

            lin2=lin+k

            Data=open(lin2,'r')

            T=json.load(Data)
            
            for top_user in T["data"]["pincodes"]:
                
                Pincodes=top_user['name']
                data_6['Pincodes'].append(Pincodes)

                Reg_Users=top_user['registeredUsers']
                data_6['RegisteredUsers'].append(Reg_Users)

                data_6['State'].append(i)
                data_6['Year'].append(j)
                data_6['Quarter'].append(int(k.strip('.json')))

#Succesfully created a dataframe
Top_User=pd.DataFrame(data_6)

Top_User["State"] = Top_User["State"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Top_User["State"] = Top_User["State"].str.replace("-"," ").str.title()
Top_User['State'] = Top_User['State'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")
Top_User
# Out:
#                   State  Year  Quarter Pincodes  RegisteredUsers
# 0     Andaman & Nicobar  2018        1   744103             1608
# 1     Andaman & Nicobar  2018        1   744101             1108
# 2     Andaman & Nicobar  2018        1   744105             1075
# 3     Andaman & Nicobar  2018        1   744102             1006
# 4     Andaman & Nicobar  2018        1   744104              272
# ...                 ...   ...      ...      ...              ...
# 8563        West Bengal  2023        4   700015           126663
# 8564        West Bengal  2023        4   742304           123320
# 8565        West Bengal  2023        4   721101           123088
# 8566        West Bengal  2023        4   700150           119283
# 8567        West Bengal  2023        4   700091           118578
#
# [8568 rows x 5 columns]

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",password="")
print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
# mycursor.execute('create database IF NOT EXISTS phonepe_db')

# %%
# Create table for Aggregated Transaction
# mycursor.execute('create table IF NOT EXISTS phonepe_db.AggTransaction(State VARCHAR(255),Year INT,Quarter INT,Transaction_type VARCHAR(255),Transaction_count INT,Transaction_amount FLOAT)')

# # Insert into the Aggregated Transaction
# Insert_Agg_Trans = [tuple(row) for row in Agg_Trans.values]
# sql_AggTrans = 'INSERT INTO phonepe_db.aggtransaction (`State`, `Year`, `Quarter`, `Transaction_type`, `Transaction_count`, `Transaction_amount`)VALUES(%s, %s, %s, %s, %s, %s)'
# mycursor.executemany(sql_AggTrans, Insert_Agg_Trans)
# mydb.commit()

# %%
# Create table for Aggregated User
# mycursor.execute('create table IF NOT EXISTS phonepe_db.AggUser(State VARCHAR(255),Year INT,Quarter INT,Brand VARCHAR(255),Counts INT,Percentage FLOAT)')

# Insert into the Aggregated Users
# Insert_Agg_Users = [tuple(row) for row in Agg_Users.values]
# sql_AggUsers = 'INSERT INTO phonepe_db.agguser(`State`, `Year`, `Quarter`, `Brand`, `Counts`, `Percentage`)VALUES(%s, %s, %s, %s, %s, %s)'
# mycursor.executemany(sql_AggUsers,Insert_Agg_Users)
# mydb.commit()

# %%
# # Create table for Map Transaction
# mycursor.execute('create table IF NOT EXISTS phonepe_db.MapTransaction(State VARCHAR(255),Year INT,Quarter INT,Districts VARCHAR(255),Transaction_count INT,Transaction_amount FLOAT)')

# # Insert into the Map Transaction
# Insert_Map_Trans = [tuple(row) for row in Map_Transaction.values]
# sql_MapTrans = 'INSERT INTO phonepe_db.maptransaction(`State`, `Year`, `Quarter`, `Districts`, `Transaction_count`, `Transaction_amount`)VALUES (%s, %s, %s, %s, %s, %s)'
# mycursor.executemany(sql_MapTrans,Insert_Map_Trans)
# mydb.commit()

# %%
# # Create table for Map User
# mycursor.execute('create table IF NOT EXISTS phonepe_db.MapUser(State VARCHAR(255),Year INT,Quarter INT,Districts VARCHAR(255),RegisteredUsers INT,AppOpens INT)')
# Insert into the Map User
# Insert_Map_User = [tuple(row) for row in Map_User.values]
# sql_MapUser = 'INSERT INTO phonepe_db.mapuser(`State`, `Year`, `Quarter`, `Districts`, `RegisteredUsers`, `AppOpens`)VALUES(%s, %s, %s, %s, %s, %s)'
# mycursor.executemany(sql_MapUser, Insert_Map_User)
# mydb.commit()

# %%
# Create table for Top Transaction
# mycursor.execute('create table IF NOT EXISTS phonepe_db.TopTransaction(State VARCHAR(255),Year INT,Quarter INT,Pincodes INT,Transaction_count INT,Transaction_amount FLOAT)')

# # # Insert into the Top Transaction
# Insert_Top_Trans = [tuple(row) for row in Top_Transaction.values]
# sql_TopTrans = 'INSERT INTO phonepe_db.toptransaction(`State`, `Year`, `Quarter`, `Pincodes`, `Transaction_count`, `Transaction_amount`) VALUES (%s, %s, %s, %s, %s, %s)'
# mycursor.executemany(sql_TopTrans, Insert_Top_Trans)
# mydb.commit()

# %%
# # # Create table for Top User
# mycursor.execute('create table IF NOT EXISTS phonepe_db.TopUser(State VARCHAR(255),Year INT,Quarter INT,Pincodes INT,RegisteredUsers INT)')

# # Insert into the Top User
# Insert_Top_Users = [tuple(row) for row in Top_User.values]
# sql_TopUser = 'INSERT INTO phonepe_db.TopUser(`State`, `Year`, `Quarter`, `Pincodes`, `RegisteredUsers`)VALUES(%s, %s, %s, %s, %s)'
# mycursor.executemany(sql_TopUser, Insert_Top_Users)
# mydb.commit()

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost",user="root",password="",database='phonepe_db')
mycursor = mydb.cursor(buffered=True)
mycursor.execute("SELECT * FROM aggtransaction")
mydb.commit()
query1=mycursor.fetchall()
df1=pd.DataFrame(query1,columns=['State','Year','Quarter','Transaction_type','Transaction_count','Transaction_amount'])
df1
# Out:
#                   State  Year  Quarter          Transaction_type  \
# 0     Andaman & Nicobar  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018        1         Merchant payments
# 3     Andaman & Nicobar  2018        1        Financial Services
# 4     Andaman & Nicobar  2018        1                    Others
# ...                 ...   ...      ...                       ...
# 4309        West Bengal  2023        4         Merchant payments
# 4310        West Bengal  2023        4     Peer-to-peer payments
# 4311        West Bengal  2023        4  Recharge & bill payments
# 4312        West Bengal  2023        4        Financial Services
# 4313        West Bengal  2023        4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845310e+06
# 1                  1871        1.213870e+07
# 2                   298        4.525070e+05
# ...

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="",database='phonepe_db')
mycursor = mydb.cursor(buffered=True)
mycursor.execute("SELECT * FROM agguser")
mydb.commit()
query2=mycursor.fetchall()
df2=pd.DataFrame(query2,columns=['State','Year','Quarter','Brand','Counts','Percentage'])
df2
# Out:
#                   State  Year  Quarter    Brand   Counts  Percentage
# 0     Andaman & Nicobar  2018        1   Xiaomi     1665    0.247033
# 1     Andaman & Nicobar  2018        1  Samsung     1445    0.214392
# 2     Andaman & Nicobar  2018        1     Vivo      982    0.145697
# 3     Andaman & Nicobar  2018        1     Oppo      501    0.074332
# 4     Andaman & Nicobar  2018        1  OnePlus      332    0.049258
# ...                 ...   ...      ...      ...      ...         ...
# 6727        West Bengal  2022        1   Lenovo   330017    0.015056
# 6728        West Bengal  2022        1  Infinix   284678    0.012987
# 6729        West Bengal  2022        1     Asus   280347    0.012790
# 6730        West Bengal  2022        1    Apple   277752    0.012671
# 6731        West Bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="",database='phonepe_db')
mycursor = mydb.cursor(buffered=True)
mycursor.execute("SELECT * FROM maptransaction")
mydb.commit()
query3=mycursor.fetchall()
df3=pd.DataFrame(query3,columns=['State','Year','Quarter','Districts','Transaction_count','Transaction_amount'])
df3
# Out:
#                    State  Year  Quarter                          Districts  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 17559        West Bengal  2023        4                     nadia district
# 17560        West Bengal  2023        4                   birbhum district
# 17561        West Bengal  2023        4           purba medinipur district
# 17562        West Bengal  2023        4                    maldah district
# 17563        West Bengal  2023        4                 darjiling district
#
#        Transaction_count  Transaction_amount
# ...

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="",database='phonepe_db')
mycursor = mydb.cursor(buffered=True)
mycursor.execute("SELECT * FROM mapuser")
mydb.commit()
query4=mycursor.fetchall()
df4=pd.DataFrame(query4,columns=['State','Year','Quarter','Districts','RegisteredUsers','AppOpens'])
df4
# Out:
#                    State  Year  Quarter                          Districts  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 17563        West Bengal  2023        4                     nadia district
# 17564        West Bengal  2023        4                   birbhum district
# 17565        West Bengal  2023        4           purba medinipur district
# 17566        West Bengal  2023        4                    maldah district
# 17567        West Bengal  2023        4                 darjiling district
#
#        RegisteredUsers  AppOpens
# 0                  632         0
# ...

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="",database='phonepe_db')
mycursor = mydb.cursor(buffered=True)
mycursor.execute("SELECT * FROM toptransaction")
mydb.commit()
query5=mycursor.fetchall()
df5=pd.DataFrame(query5,columns=['State','Year','Quarter','Pincodes','Transaction_count','Transaction_amount'])
df5
# Out:
#                   State  Year  Quarter  Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2018        1  744101.0               1622
# 1     Andaman & Nicobar  2018        1  744103.0               1223
# 2     Andaman & Nicobar  2018        1  744102.0                969
# 3     Andaman & Nicobar  2018        1  744105.0                685
# 4     Andaman & Nicobar  2018        1  744104.0                340
# ...                 ...   ...      ...       ...                ...
# 8562        West Bengal  2023        4  721301.0            4133775
# 8563        West Bengal  2023        4  700001.0            3983241
# 8564        West Bengal  2023        4  732125.0            3950411
# 8565        West Bengal  2023        4  700039.0            3742452
# 8566        West Bengal  2023        4  700014.0            3652710
#
#       Transaction_amount
# 0           2.769300e+06
# 1           2.238040e+06
# 2           3.519060e+06
# 3           1.298560e+06
# ...

# %%
mydb = mysql.connector.connect(host="localhost",user="root",password="",database='phonepe_db')
mycursor = mydb.cursor(buffered=True)
mycursor.execute("SELECT * FROM topuser")
mydb.commit()
query6=mycursor.fetchall()
df6=pd.DataFrame(query6,columns=['State','Year','Quarter','Pincodes','RegisteredUsers'])
df6
# Out:
#                   State  Year  Quarter  Pincodes  RegisteredUsers
# 0     Andaman & Nicobar  2018        1    744103             1608
# 1     Andaman & Nicobar  2018        1    744101             1108
# 2     Andaman & Nicobar  2018        1    744105             1075
# 3     Andaman & Nicobar  2018        1    744102             1006
# 4     Andaman & Nicobar  2018        1    744104              272
# ...                 ...   ...      ...       ...              ...
# 8563        West Bengal  2023        4    700015           126663
# 8564        West Bengal  2023        4    742304           123320
# 8565        West Bengal  2023        4    721101           123088
# 8566        West Bengal  2023        4    700150           119283
# 8567        West Bengal  2023        4    700091           118578
#
# [8568 rows x 5 columns]

# %%
# Agg_Trans.to_csv('AggTrans.csv', index=False)
# Agg_Users.to_csv('AggUsers.csv',index=False)
# Map_Transaction.to_csv('MapTransaction.csv',index=False)
# Map_User.to_csv('MapUser.csv',index=False)
# Top_Transaction.to_csv('TopTransaction.csv',index=False)
# Top_User.to_csv('TopUser.csv',index=False)

# %%
import pandas as pd
import plotly.express as px

file1 = pd.read_csv("AggTrans.csv")

fig = px.choropleth(
    file1,
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations='State',
    color="Transaction_count")

fig.update_geos(fitbounds="locations", visible=False)

fig.show()
